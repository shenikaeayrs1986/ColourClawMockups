# %% [markdown]
# Anaylsis of Trends for Hartis Consulting Metadata SEO

# %%
# %pip install bs4
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/129.4 kB ? eta -:--:--
#      ------------------ -------------------- 61.4/129.4 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 129.4/129.4 kB 2.5 MB/s eta 0:00:00
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=1dcf18ac85750fb3e9c22a9168ccf48629af2579476e1f77d806472ab82b52d9
#   Stored in directory: c:\users\sheni\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...

# %% [markdown]
# Get URL Hartis Consulting

# %%
from urllib.request import urlopen
html = urlopen('https://hartisconsulting.com/')
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1"/><title>Home</title><meta name="description" content="Our mission is to provide our clients with expert IT solutions and consulting services that will help them succeed in their business goals. "/><meta name="author" content="Hartis Consulting"/><meta name="generator" content="Starfield Technologies; Go Daddy Website Builder 8.0.0000"/><link rel="manifest" href="/manifest.webmanifest"/><link rel="apple-touch-icon" sizes="57x57" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:57,h:57,m"/><link rel="apple-touch-icon" sizes="60x60" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:60,h:60,m"/><link rel="apple-touch-icon" sizes="72x72" href="//img1.wsimg.com/isteam/ip/
# ...

# %%
# %pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.3 MB 2.2 MB/s eta 0:00:05
#       --------------------------------------- 0.2/10.3 MB 2.4 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/10.3 MB 3.1 MB/s eta 0:00:04
#      -- ------------------------------------- 0.6/10.3 MB 3.0 MB/s eta 0:00:04
#      --- ------------------------------------ 0.8/10.3 MB 3.3 MB/s eta 0:00:03
#      --- ------------------------------------ 0.9/10.3 MB 3.3 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.1/10.3 MB 3.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.2/10.3 MB 3.3 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.4/10.3 MB 3.3 MB/s eta 0:00:03
#      ------ --------------------------------- 1.6/10.3 MB 3.3 MB/s eta 0:00:03
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#       --------------------------------------- 0.2/7.6 MB 5.0 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/7.6 MB 6.0 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/7.6 MB 10.4 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.0/7.6 MB 11.7 MB/s eta 0:00:01
#      -------------- ------------------------- 2.8/7.6 MB 12.6 MB/s eta 0:00:01
#      ------------------- -------------------- 3.7/7.6 MB 13.8 MB/s eta 0:00:01
#      ----------------------- ---------------- 4.5/7.6 MB 14.3 MB/s eta 0:00:01
#      --------------------------- ------------ 5.2/7.6 MB 14.3 MB/s eta 0:00:01
#      ------------------------------- -------- 6.0/7.6 MB 15.5 MB/s eta 0:00:01
#      ------------------------------------ --- 7.0/7.6 MB 15.4 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 15.1 MB/s eta 0:00:01
# ...

# %%
# %pip install json
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
# %pip install e-commerce
# Out:
# ...
#
# ...

# %%
# %pip install selenium
# Out:
# ...
#      ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/6.9 MB 1.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/6.9 MB 3.8 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.7/6.9 MB 5.8 MB/s eta 0:00:02
#      ------- -------------------------------- 1.3/6.9 MB 6.7 MB/s eta 0:00:01
#      ---------- ----------------------------- 1.8/6.9 MB 8.0 MB/s eta 0:00:01
#      -------------- ------------------------- 2.5/6.9 MB 9.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 3.1/6.9 MB 9.4 MB/s eta 0:00:01
#      --------------------- ------------------ 3.8/6.9 MB 10.1 MB/s eta 0:00:01
#      -------------------------- ------------- 4.6/6.9 MB 11.3 MB/s eta 0:00:01
#      -------------------------------- ------- 5.6/6.9 MB 12.4 MB/s eta 0:00:01
#      ------------------------------------ --- 6.3/6.9 MB 12.7 MB/s eta 0:00:01
# ...

# %%
# %pip install extruct
# Out:
# ...
#      ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#      - -------------------------------------- 0.1/3.8 MB 3.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.4/3.8 MB 4.5 MB/s eta 0:00:01
#      -------- ------------------------------- 0.8/3.8 MB 5.3 MB/s eta 0:00:01
#      -------------- ------------------------- 1.4/3.8 MB 7.9 MB/s eta 0:00:01
#      --------------------- ------------------ 2.1/3.8 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.2/3.8 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 12.6 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 11.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/121.9 kB ? eta -:--:--
#      -------------------------------------- 121.9/121.9 kB 7.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
urls = ['https://hartisconsulting.com/','https://colourclaw.co/']

# %%
# %pip install ecommercetools
# Out:
# ...
#   Using cached ecommercetools-0.42.9-py3-none-any.whl (50 kB)
# ...
#   Using cached gapandas-1.0-py3-none-any.whl (12 kB)
# ...
#   Using cached httplib2-0.21.0-py3-none-any.whl (96 kB)
# ...
#   Using cached Lifetimes-0.11.3-py3-none-any.whl (584 kB)
# ...
#   Using cached pycausalimpact-0.1.1-py2.py3-none-any.whl (30 kB)
# ...
#   Using cached requests_html-0.10.0-py3-none-any.whl (13 kB)
# ...
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/49.9 kB ? eta -:--:--
#      ---------------------------------------- 49.9/49.9 kB 2.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/49.9 kB ? eta -:--:--
#      ---------------------------------------- 49.9/49.9 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/49.9 kB ? eta -:--:--
#      ---------------------------------------- 49.9/49.9 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# %pip install flask
# Out:
# ...
#      ---------------------------------------- 0.0/101.8 kB ? eta -:--:--
#      ----------------------------------- --- 92.2/101.8 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 101.8/101.8 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/233.6 kB ? eta -:--:--
#      ---------------------------- --------- 174.1/233.6 kB 3.5 MB/s eta 0:00:01
#      -------------------------------------- 233.6/233.6 kB 3.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/133.1 kB ? eta -:--:--
#      ----------------------------------- -- 122.9/133.1 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 133.1/133.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 5.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %pip install --upgrade google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# ...
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      --------------------- ----------------- 81.9/151.7 kB 1.5 MB/s eta 0:00:01
#      ----------------------------------- -- 143.4/151.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 151.7/151.7 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'c:\Users\sheni\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install --upgrade requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Interest Over Time assessment

# %%
import pytrends
from pytrends.request import TrendReq
import pandas as pd
import time
import datetime
from datetime import datetime, date, time

# %%
pytrend = TrendReq()
pytrend.build_payload(kw_list =[ 'hartis consulting', 'IT Consulting', 'Cloud', 'big data', 'AI'], timeframe='today 12-m', geo = 'GB', cat= 1162)

# %%
pytrend.interest_over_time()
interest_over_time_df = pytrend.interest_over_time()
print(interest_over_time_df.head())
# Out:
#             hartis consulting  IT Consulting  Cloud  big data  AI  isPartial
# date
# 2022-02-20                  0             22     59         0   0      False
# 2022-02-27                  0              0      0         0  42      False
# 2022-03-06                  0             48      0         0   0      False
# 2022-03-13                  0              0      0         0   0      False
# 2022-03-20                  0              0     17         0  19      False

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel ('Date')
dx.set_ylabel ('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)

# %% [markdown]
# Suggested Keywords

# %%
print(pytrend.suggestions(keyword= 'IT Consulting'), '\n')
print(pytrend.suggestions(keyword= 'Consulting'), '\n')
print(pytrend.suggestions(keyword= 'Cloud Security'), '\n')
print(pytrend.suggestions(keyword= 'Active Directory'), '\n')
print(pytrend.suggestions(keyword= 'Technical Consulting'), '\n')
# Out:
# [{'mid': '/m/07k6dg', 'title': 'Information technology consulting', 'type': 'Field of study'}, {'mid': '/g/11bc61bhp0', 'title': 'GFT IT Consulting, S.L.', 'type': 'Topic'}, {'mid': '/g/11bc5llhgx', 'title': 'IT consulting company', 'type': 'Company'}, {'mid': '/g/11b7q9r7cn', 'title': 'Adaptive Leadership: The Heifetz Collection (3 Items)', 'type': 'Book by Alexander Grashow, Marty Linsky, and Ronald Heifetz'}, {'mid': '/g/12bnmvbh7', 'title': 'Getting Naked: A Business Fable About Shedding The Three Fears That Sabotage Client Loyalty', 'type': 'Book by Patrick Lencioni'}]
#
# ...

# %% [markdown]
# Related Queries for Google Trends Category Consulting: 1162

# %%
pytrend.build_payload(kw_list= ['IT Consulting Services', 'Consulting', 'Network Administrator', 'Cloud Security'], geo= 'US', timeframe = 'today 3-m', cat = 1162)
related_queries= pytrend.related_queries()
print(related_queries)
# Out:
# {'IT Consulting Services': {'top': None, 'rising': None}, 'Consulting': {'top':                           query  value
# 0              consulting firms    100
# 1           business consulting     81
# 2         management consulting     53
# 3       boston consulting group     36
# 4               consulting firm     35
# 5          consulting companies     34
# 6           mckinsey consulting     30
# 7           deloitte consulting     28
# 8         healthcare consulting     22
# 9        engineering consulting     20
# 10         marketing consulting     20
# 11         top consulting firms     16
# 12              bain consulting     13
# 13               pwc consulting     11
# 14            slalom consulting     11
# 15             huron consulting     10
# 16        best consulting firms     10
# 17  management consulting firms      9
# 18            consulting agency      5
# 19   financial consulting firms      4
# 20          edgility consulting      3
# ...

# %% [markdown]
# Rising Keywords for Consulting

# %%
pytrend.build_payload(kw_list=[ 'Consulting', 'IT Consulting', 'Cloud', 'big data', 'AI'], geo= 'US', timeframe= 'today 3-m', cat =1162)
related_queries = pytrend.related_queries()
dg = related_queries.get('Consulting').get('rising')
dg
# Out:
#                                query  value
# 0                  vendor consulting   9650
# 1                  embark consulting   9050
# 2                farallon consulting   8500
# 3                     mei consulting   8400
# 4          halloran consulting group   7950
# 5                nemanich consulting   6650
# 6                      jc consulting   5850
# 7   best healthcare consulting firms   5550
# 8                     888 consulting   5400
# 9                edgility consulting    500
# 10        financial consulting firms    350
# 11                  azure consulting    300
# 12            180 degrees consulting    180
# 13               activate consulting    170
# 14                 consulting agency    130
# 15           triple crown consulting    120
# 16                   lean consulting    120
# 17                artemis consulting    120
# 18       creative medical consulting    110
# 19          social impact consulting    110
