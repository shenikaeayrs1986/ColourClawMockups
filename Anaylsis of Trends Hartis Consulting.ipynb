# %% [markdown]
# # Anaylsis of Trends for Hartis Consulting Metadata SEO

# %%
# %pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Get URL Hartis Consulting

# %%
from urllib.request import urlopen
html = urlopen('https://hartisconsulting.com/')
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1"/><title>Home</title><meta name="description" content="Our mission is to provide our clients with expert IT solutions and consulting services that will help them succeed in their business goals. "/><meta name="author" content="Hartis Consulting"/><meta name="generator" content="Starfield Technologies; Go Daddy Website Builder 8.0.0000"/><link rel="manifest" href="/manifest.webmanifest"/><link rel="apple-touch-icon" sizes="57x57" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:57,h:57,m"/><link rel="apple-touch-icon" sizes="60x60" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:60,h:60,m"/><link rel="apple-touch-icon" sizes="72x72" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:72,h:72,m"/><link rel="apple-touch-icon" sizes="114x114" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:114,h:114,m"/><link rel="apple-touch-icon" sizes="120x120" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:120,h:120,m"/><link rel="apple-touch-icon" sizes="144x144" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:144,h:144,m"/><link rel="apple-touch-icon" sizes="152x152" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:152,h:152,m"/><link rel="apple-touch-icon" sizes="180x180" href="//img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png/:/rs=w:180,h:180,m"/><meta property="og:url" content="https://hartisconsulting.com/home"/>\n<meta property="og:site_name" content="Hartis Consulting"/>\n<meta property="og:title" content="Hartis Consulting"/>\n<meta property="og:description" content="Our mission is to provide our clients with expert IT solutions and consulting services that will help them succeed in their business goals. "/>\n<meta property="og:type" content="website"/>\n<meta property="og:image" content="https://img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png"/>\n<meta property="og:locale" content="en_US"/>\n<meta name="twitter:card" content="summary"/>\n<meta name="twitter:title" content="Hartis Consulting"/>\n<meta name="twitter:description" content="Our mission is to provide our clients with expert IT solutions and consulting services that will help them succeed in their business goals. "/>\n<meta name="twitter:image" content="https://img1.wsimg.com/isteam/ip/d725e997-82ab-4cca-9e64-6f7868b7f057/HC%20Logo%201%20Black%20white%20blue.png"/>\n<meta name="twitter:image:alt" content="Hartis Consulting"/>\n<meta name="theme-color" content="#3261e1"/>\n<meta name="google-site-verification" content="I-Kop9PzO4OdAURWcg_I0niow8o4GotZAvmHDrxRe0k"/><style data-inline-fonts>@font-face {\n  font-family: \'Sacramento\';\n  font-style: normal;\n  font-weight: 400;\n  font-display: swap;\n  src: url(https://img1.wsimg.com/gfonts/s/sacramento/v13/buEzpo6gcdjy0EiZMBUG4C0f-w.woff) format(\'woff\');\n}\n\n@font-face {\n  font-family: \'Raleway\';\n  font-style: italic;\n  font-weight: 400;\n  font-display: swap;\n  src: url(https://img1.wsimg.com/gfonts/s/raleway/v28/1Pt_g8zYS_SKggPNyCgSQamb1W0lwk4S4WjMDrMfJg.woff) format(\'woff\');\n}\n@font-face {\n  font-family: \'Raleway\';\n  font-style: normal;\n  font-weight: 300;\n  font-display: swap;\n  src: url(https://img1.wsimg.com/gfonts/s/raleway/v28/1Ptxg8zYS_SKggPN4iEgvnHyvveLxVuEorCIPrc.woff) format(\'woff\');\n}\n@font-face {\n  font-family: \'Ralewa ...

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install json
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
# %pip install e-commerce
# Out:
# Requirement already satisfied: e-commerce in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (4.8.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install extruct
# Out:
# Requirement already satisfied: extruct in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.14.0)
# Requirement already satisfied: lxml in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (4.9.2)
# Requirement already satisfied: pyrdfa3 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (3.5.3)
# Requirement already satisfied: mf2py in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (1.1.2)
# Requirement already satisfied: w3lib in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (2.1.1)
# Requirement already satisfied: html-text>=0.5.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (0.5.2)
# Requirement already satisfied: six in c:\users\sheni\appdata\roaming\python\python311\site-packages (from extruct) (1.16.0)
# Requirement already satisfied: jstyleson in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (0.0.2)
# Requirement already satisfied: rdflib>=6.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from extruct) (6.2.0)
# Requirement already satisfied: isodate in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from rdflib>=6.0.0->extruct) (0.6.1)
# Requirement already satisfied: pyparsing in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from rdflib>=6.0.0->extruct) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from rdflib>=6.0.0->extruct) (67.3.2)
# Requirement already satisfied: html5lib>=1.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from mf2py->extruct) (1.1)
# Requirement already satisfied: requests>=2.18.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from mf2py->extruct) (2.28.2)
# Requirement already satisfied: BeautifulSoup4>=4.6.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from mf2py->extruct) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from BeautifulSoup4>=4.6.0->mf2py->extruct) (2.4)
# Requirement already satisfied: webencodings in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from html5lib>=1.0.1->mf2py->extruct) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.18.4->mf2py->extruct) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.18.4->mf2py->extruct) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.18.4->mf2py->extruct) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.18.4->mf2py->extruct) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
urls = ['https://hartisconsulting.com/','https://colourclaw.co/']

# %%
# %pip install ecommercetools
# Out:
# Requirement already satisfied: ecommercetools in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.24)
# Requirement already satisfied: pandas in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (1.5.3)
# Requirement already satisfied: gapandas in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (1.0)
# Requirement already satisfied: sklearn in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (0.0.post1)
# Requirement already satisfied: requests in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (2.28.2)
# Requirement already satisfied: requests-html in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (0.10.0)
# Requirement already satisfied: httplib2>=0.15.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (0.21.0)
# Requirement already satisfied: lifetimes in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from ecommercetools) (0.11.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from httplib2>=0.15.0->ecommercetools) (3.0.9)
# Requirement already satisfied: google-api-python-client in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from gapandas->ecommercetools) (2.78.0)
# Requirement already satisfied: oauth2client in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from gapandas->ecommercetools) (4.1.3)
# Requirement already satisfied: numpy>=1.10.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from lifetimes->ecommercetools) (1.24.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from lifetimes->ecommercetools) (1.10.0)
# Requirement already satisfied: autograd>=1.2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from lifetimes->ecommercetools) (1.5)
# Requirement already satisfied: dill>=0.2.6 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from lifetimes->ecommercetools) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from pandas->ecommercetools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas->ecommercetools) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests->ecommercetools) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests->ecommercetools) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests->ecommercetools) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests->ecommercetools) (2022.12.7)
# Requirement already satisfied: pyquery in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (2.0.0)
# Requirement already satisfied: fake-useragent in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (1.1.1)
# Requirement already satisfied: parse in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (1.19.0)
# Requirement already satisfied: bs4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (2.1.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-html->ecommercetools) (1.0.2)
# Requirement already satisfied: future>=0.15.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from autograd>=1.2.0->lifetimes->ecommercetools) (0.18.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (6.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (4.64.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyppeteer>=0.0.14->requests-html->ecommercetools) (10.4)
# Requirement already satisfied: six>=1.5 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas->ecommercetools) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from bs4->requests-html->ecommercetools) (4.11.2)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->gapandas->ecommercetools) (2.16.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->gapandas->ecommercetools) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->gapandas->ecommercetools) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client->gapandas->ecommercetools) (4.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from oauth2client->gapandas->ecommercetools) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from oauth2client->gapandas->ecommercetools) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from oauth2client->gapandas->ecommercetools) (4.9)
# Requirement already satisfied: lxml>=2.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyquery->requests-html->ecommercetools) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyquery->requests-html->ecommercetools) (1.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->gapandas->ecommercetools) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->gapandas->ecommercetools) (4.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client->gapandas->ecommercetools) (5.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->ecommercetools) (3.14.0)
# Requirement already satisfied: colorama in c:\users\sheni\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html->ecommercetools) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->bs4->requests-html->ecommercetools) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from flask) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from flask) (8.1.3)
# Requirement already satisfied: colorama in c:\users\sheni\appdata\roaming\python\python311\site-packages (from click>=8.0->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.0->flask) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (2.78.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.16.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.22.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# Requirement already satisfied: google-auth in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (2.16.1)
# Requirement already satisfied: google-auth-oauthlib in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (1.0.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from google-auth) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: httplib2>=0.15.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from google-auth-httplib2) (0.21.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from httplib2>=0.15.0->google-auth-httplib2) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade requests
# Out:
# Requirement already satisfied: requests in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (4.9.0)
# Requirement already satisfied: requests>=2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.28.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (1.5.3)
# Requirement already satisfied: lxml in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (1.24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Interest Over Time Assessment

# %%
import pytrends
from pytrends.request import TrendReq
import pandas as pd
import time
import datetime
from datetime import datetime, date, time

# %%
pytrend = TrendReq()
pytrend.build_payload(kw_list =[ 'hartis consulting', 'IT Consulting', 'Cloud', 'big data', 'AI'], timeframe='today 12-m', geo = 'GB', cat= 1162)

# %%
pytrend.interest_over_time()
interest_over_time_df = pytrend.interest_over_time()
print(interest_over_time_df)
# Out:
#             Consulting  IT Consulting  Cloud  big data  AI  isPartial
# date
# 2022-11-20          24              0      0         0   0      False
# 2022-11-21          71              0      0         0   0      False
# 2022-11-22          59              4      0         0   0      False
# 2022-11-23          62              4      0         0   0      False
# 2022-11-24          24              0      3         0   0      False
# ...                ...            ...    ...       ...  ..        ...
# 2023-02-12          43              0      0         0   0      False
# 2023-02-13          77              0      0         0   0      False
# 2023-02-14          78              4      0         0   0      False
# 2023-02-15          92              2      0         0   0      False
# 2023-02-16          99              0      3         2   0      False
#
# [89 rows x 6 columns]

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\sheni\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = interest_over_time_df.plot.line(figsize = (9,6), title = "Interest Over Time")
dx.set_xlabel ('Date')
dx.set_ylabel ('Trends Index')
dx.tick_params(axis='both', which='major', labelsize=13)

# %% [markdown]
# ### Google Suggested Keywords Assessment

# %%
print(pytrend.suggestions(keyword= 'IT Consulting'), '\n')
print(pytrend.suggestions(keyword= 'Consulting'), '\n')
print(pytrend.suggestions(keyword= 'Cloud Security'), '\n')
print(pytrend.suggestions(keyword= 'Active Directory'), '\n')
print(pytrend.suggestions(keyword= 'Technical Consulting'), '\n')
# Out:
# [{'mid': '/m/07k6dg', 'title': 'Information technology consulting', 'type': 'Field of study'}, {'mid': '/g/11bc61bhp0', 'title': 'GFT IT Consulting, S.L.', 'type': 'Topic'}, {'mid': '/g/11bc5llhgx', 'title': 'IT consulting company', 'type': 'Company'}, {'mid': '/g/11b7q9r7cn', 'title': 'Adaptive Leadership: The Heifetz Collection (3 Items)', 'type': 'Book by Alexander Grashow, Marty Linsky, and Ronald Heifetz'}, {'mid': '/g/12bnmvbh7', 'title': 'Getting Naked: A Business Fable About Shedding The Three Fears That Sabotage Client Loyalty', 'type': 'Book by Patrick Lencioni'}]
#
# [{'mid': '/g/120vzy67', 'title': 'consulting', 'type': 'Topic'}, {'mid': '/g/11c59khsh8', 'title': 'Danielle DiMartino Booth', 'type': 'Economist'}, {'mid': '/g/11jp05f7hg', 'title': 'The 80/80 Marriage: A New Model for a Happier, Stronger Relationship', 'type': 'Book by Kaley Klemp and Nate Klemp PhD'}, {'mid': '/g/11b7q9r7cn', 'title': 'Adaptive Leadership: The Heifetz Collection (3 Items)', 'type': 'Book by Alexander Grashow, Marty Linsky, and Ronald Heifetz'}, {'mid': '/g/11f7blws4y', 'title': 'Shawn Baker', 'type': 'Author'}]
#
# [{'mid': '/m/09v8lc9', 'title': 'Cloud computing security', 'type': 'Topic'}, {'mid': '/g/11bwps6d29', 'title': 'Office 365 For Dummies', 'type': 'Book by Jennifer Bond Reed, Ken Withee, and Rosemarie Withee'}, {'mid': '/m/0rpjdzl', 'title': 'Cloud Security Alliance', 'type': 'Not-for-profit organization'}, {'mid': '/g/11b60j9m_8', 'title': 'QuickBooks Online For Dummies', 'type': 'Book by Elaine J Marmel'}, {'mid': '/g/11g_ybd6pt', 'title': 'Exam Ref AZ-900 Microsoft Azure Fundamentals', 'type': 'Book by Jim Cheshire'}]
#
# [{'mid': '/m/011bm', 'title': 'Active Directory', 'type': 'System software'}, {'mid': '/m/02p0xxs', 'title': 'ActiveX', 'type': 'Software framework'}, {'mid': '/m/063_jl8', 'title': 'Active Directory Federation Services', 'type': 'Software'}, {'mid': '/m/02vz3d0', 'title': 'Active Directory Explorer', 'type': 'Software'}, {'mid': '/m/08fw81', 'title': 'Active Directory Rights Management Services', 'type': 'Topic'}]
#
# [{'mid': '/g/1tj99g2v', 'title': 'Tecdatum - Management & Technical Consulting Company', 'type': 'Consultant in Hyderabad, India'}, {'mid': '/m/06hpk2z', 'title': 'Electrical Engineering Drawing', 'type': 'Book by Sabyasachi Bhattacharya'}, {'mid': '/g/12bnh3m0x', 'title': 'The Art of Scalability: Scalable Web Architecture, Processes, and Organizations for the Modern Enterprise', 'type': 'Book by Martin L. Abbott and Michael T. Fisher'}]

# %% [markdown]
# ### Related Queries for Google Trends Category Consulting: 1162 Assessment

# %%
pytrend.build_payload(kw_list= ['IT Consulting Services', 'Consulting', 'Network Administrator', 'Cloud Security'], geo= 'US', timeframe = 'today 3-m', cat = 1162)
related_queries= pytrend.related_queries()
print(related_queries)
# Out:
# {'IT Consulting Services': {'top': None, 'rising': None}, 'Consulting': {'top':                         query  value
# 0            consulting firms    100
# 1         business consulting     81
# 2       management consulting     52
# 3           consulting salary     38
# 4     boston consulting group     36
# 5             consulting firm     35
# 6        consulting companies     33
# 7         mckinsey consulting     31
# 8         deloitte consulting     28
# 9             consulting jobs     26
# 10      healthcare consulting     24
# 11        strategy consulting     21
# 12       marketing consulting     19
# 13     engineering consulting     19
# 14       accenture consulting     14
# 15          reddit consulting     12
# 16            bain consulting     12
# 17           huron consulting     10
# 18  small business consulting      9
# 19          consulting agency      5
# 20  private equity consulting      4
# 21        activate consulting      2
# 22       foothills consulting      2
# 23  slalom consulting careers      2
# 24        1connect consulting      1, 'rising':                                 query  value
# 0           slalom consulting careers  13300
# 1           halloran consulting group  12100
# 2                      888 consulting   8650
# 3                      nbd consulting   8300
# 4                    azure consulting   7300
# 5                 activate consulting    250
# 6      sunlight consulting and events    150
# 7   best consulting firms to work for    100
# 8           private equity consulting    100
# 9                   consulting agency     90
# 10            triple crown consulting     80
# 11               foothills consulting     80
# 12                1connect consulting     70
# 13          small business consulting     60
# 14                  v soft consulting     60}, 'Network Administrator': {'top': None, 'rising': None}, 'Cloud Security': {'top': None, 'rising': None}}

# %% [markdown]
# ### Google Rising Keywords for Consulting Assessment

# %%
pytrend.build_payload(kw_list=[ 'Consulting', 'IT Consulting', 'Cloud', 'big data', 'AI'], geo= 'US', timeframe= 'today 3-m', cat =1162)
related_queries = pytrend.related_queries()
dg = related_queries.get('Consulting').get('rising')
dg
# Out:
#                                 query  value
# 0           slalom consulting careers  13300
# 1           halloran consulting group  12100
# 2                      888 consulting   8650
# 3                      nbd consulting   8300
# 4                    azure consulting   7300
# 5                 activate consulting    250
# 6      sunlight consulting and events    150
# 7   best consulting firms to work for    100
# 8           private equity consulting    100
# 9                   consulting agency     90
# 10            triple crown consulting     80
# 11               foothills consulting     80
# 12                1connect consulting     70
# 13          small business consulting     60
# 14                  v soft consulting     60

# %%
import pandas as pd
import json
import requests

# %%
import requests
response = requests.get("https://hartisconsulting.com/")

# %%
# %pip install godaddypy
# Out:
# Requirement already satisfied: godaddypy in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (2.3.4)
# Requirement already satisfied: requests>=2.4 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from godaddypy) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.4->godaddypy) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.4->godaddypy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.4->godaddypy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheni\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.4->godaddypy) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Google Search Console Performance Import Hartis Consulting Duration = 12 months Assessment

# %%
import pandas as pd
data = pd.read_csv("/Users/sheni/Downloads/Queries.csv")
data.head()
# Out:
#      Top queries  Clicks  Impressions    CTR  Position
# 0  shenika eayrs       2           24  8.33%      7.75
# 1    colour mill       0            6     0%     10.83
# 2      colormill       0            1     0%     11.00

# %%
import pandas as pd
data = pd.read_csv("/Users/sheni/Downloads/Pages.csv")
print(data)
# Out:
#                                            Top pages  Clicks  Impressions  \
# 0                  https://hartisconsulting.com/home       5           16
# 1                https://hartisconsulting.com/it-hub       3           28
# 2              https://hartisconsulting.com/about-us       1           13
# 3  https://hartisconsulting.com/it-hub/f/why-you-...       1            2
# 4  https://hartisconsulting.com/consultation-request       0           58
# 5              https://hartisconsulting.com/services       0            3
# 6                      https://hartisconsulting.com/       0            3
# 7  https://hartisconsulting.com/media/f/mitigate-...       0            3
# 8            https://hartisconsulting.com/contact-us       0            3
# 9  https://hartisconsulting.com/media/f/data-loss...       0            1
#
#       CTR  Position
# 0  31.25%      1.88
# 1  10.71%     12.79
# 2   7.69%      3.85
# 3     50%     18.00
# 4      0%      9.07
# 5      0%      2.00
# 6      0%      2.33
# 7      0%      8.33
# 8      0%     92.67
# 9      0%     80.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
dx = data.plot.line(figsize = (9,6), title = "Page Assement")
dx.set_xlabel ('Impressions')
dx.set_ylabel ('Position')
dx.tick_params(axis='both', which='major', labelsize=13)

# %%
data = pd.read_csv("/Users/sheni/Downloads/Devices.csv")
data.head()
# Out:
#     Device  Clicks  Impressions    CTR  Position
# 0   Mobile       9           90    10%      7.81
# 1  Desktop       1           28  3.57%     20.32

# %%
data = pd.read_csv("/Users/sheni/Downloads/Countries.csv")
data.head()
# Out:
#           Country  Clicks  Impressions   CTR  Position
# 0   United States      10          101  9.9%     11.00
# 1          France       0            3    0%      4.33
# 2           India       0            3    0%     32.33
# 3  United Kingdom       0            2    0%      1.00
# 4          Norway       0            2    0%      1.00

# %%
data = pd.read_csv("/Users/sheni/Downloads/Dates.csv")
data.head()
# Out:
#          Date  Clicks  Impressions CTR  Position
# 0  2023-02-18       0            0  0%      0.00
# 1  2023-02-17       0            3  0%      7.00
# 2  2023-02-16       0            2  0%      7.50
# 3  2023-02-15       0            3  0%     30.67
# 4  2023-02-14       0            0  0%      0.00

# %%
data = pd.read_csv("/Users/sheni/Downloads/Filters.csv")
data.head()
# Out:
#         Filter           Value
# 0  Search type             Web
# 1         Date  Last 12 months

# %%
data = pd.read_csv("/Users/sheni/Downloads/Search appearance.csv")
data.head()
# Out:
# Empty DataFrame
# Columns: [Search Appearance, Clicks, Impressions, CTR, Position]
# Index: []
